# %% [markdown]
# # Torchy demo on Iris Species dataset

# %% [markdown]
# ### Import essential dependencies

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import load_iris
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Install and import Torchy dependencies

# %%
pip install torchy-nn
# Out:
# Collecting torchy-nn
#   Downloading torchy_nn-0.3.5.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchy-nn) (1.23.5)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.10/site-packages (from torchy-nn) (7.4.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.10/site-packages (from pytest->torchy-nn) (2.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from pytest->torchy-nn) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/lib/python3.10/site-packages (from pytest->torchy-nn) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/conda/lib/python3.10/site-packages (from pytest->torchy-nn) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pytest->torchy-nn) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->pytest->torchy-nn) (3.0.9)
# Installing collected packages: torchy-nn
# Successfully installed torchy-nn-0.3.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import torchy.nn as nn
import torchy.optimizers as optim

# %%
np.random.seed(42)

# %% [markdown]
# ### Load Iris dataset

# %%
X, y = load_iris(return_X_y=True)

plt.scatter(X[:,0], X[:,1], c=y)

# %% [markdown]
# ### Define Torchy model

# %%
# Defining process works exactly the same as if it were done with PyTorch

model = nn.Sequential(
    nn.Linear(4, 50,),
    nn.BatchNorm1d(50),
    nn.ReLU(),
    nn.Linear(50, 3)
)

criterion = nn.CrossEntropyLoss()
optimizer = optim.MomentumSGD(model.params, lr=1e-2)  # Model parameters called as property and not as class method.

# %% [markdown]
# ### Define train function

# %%
def train_model(X, y, model, criterion, optimizer, n_epochs=40):
    loss_history = []
    acc_history = []
    
    for epoch in range(n_epochs):
        
        predictions = model(X)
        
        # First difference is every loss object returns loss and its gradient
        loss, grad = criterion(predictions, y)
        
        optimizer.zero_grad()
        model.backward(grad)  # Call backward on model object and pass gradient from loss as argument
        optimizer.step()
        
        pred_indices = np.argmax(predictions, axis=1)
        accuracy = (np.sum(y == pred_indices)) / y.shape[0]
        
        acc_history.append(accuracy)
        loss_history.append(loss)
        
        print(f"Epoch #{epoch} | Accuracy: {np.round(accuracy * 100, 2)}% | Loss: {np.round(loss, 2)}")
        
    return loss_history, acc_history

# %% [markdown]
# ### Training process

# %%
loss_history, acc_history = train_model(X, y, model, criterion, optimizer)
# Out:
# Epoch #0 | Accuracy: 37.33% | Loss: 1.38
# Epoch #1 | Accuracy: 37.33% | Loss: 1.3
# Epoch #2 | Accuracy: 38.0% | Loss: 1.17
# Epoch #3 | Accuracy: 43.33% | Loss: 1.0
# Epoch #4 | Accuracy: 68.67% | Loss: 0.83
# Epoch #5 | Accuracy: 80.67% | Loss: 0.69
# Epoch #6 | Accuracy: 83.33% | Loss: 0.58
# Epoch #7 | Accuracy: 86.0% | Loss: 0.51
# Epoch #8 | Accuracy: 87.33% | Loss: 0.45
# Epoch #9 | Accuracy: 86.67% | Loss: 0.42
# Epoch #10 | Accuracy: 86.67% | Loss: 0.39
# Epoch #11 | Accuracy: 86.0% | Loss: 0.37
# Epoch #12 | Accuracy: 84.67% | Loss: 0.35
# Epoch #13 | Accuracy: 84.0% | Loss: 0.34
# Epoch #14 | Accuracy: 84.67% | Loss: 0.32
# Epoch #15 | Accuracy: 85.33% | Loss: 0.31
# Epoch #16 | Accuracy: 87.33% | Loss: 0.3
# Epoch #17 | Accuracy: 87.33% | Loss: 0.3
# Epoch #18 | Accuracy: 88.0% | Loss: 0.29
# Epoch #19 | Accuracy: 88.67% | Loss: 0.28
# Epoch #20 | Accuracy: 88.67% | Loss: 0.27
# Epoch #21 | Accuracy: 89.33% | Loss: 0.26
# Epoch #22 | Accuracy: 90.0% | Loss: 0.26
# Epoch #23 | Accuracy: 91.33% | Loss: 0.25
# Epoch #24 | Accuracy: 91.33% | Loss: 0.25
# Epoch #25 | Accuracy: 91.33% | Loss: 0.24
# Epoch #26 | Accuracy: 92.0% | Loss: 0.24
# Epoch #27 | Accuracy: 92.0% | Loss: 0.23
# Epoch #28 | Accuracy: 92.67% | Loss: 0.23
# Epoch #29 | Accuracy: 92.67% | Loss: 0.22
# Epoch #30 | Accuracy: 93.33% | Loss: 0.22
# Epoch #31 | Accuracy: 94.0% | Loss: 0.22
# Epoch #32 | Accuracy: 94.67% | Loss: 0.21
# Epoch #33 | Accuracy: 94.67% | Loss: 0.21
# Epoch #34 | Accuracy: 94.67% | Loss: 0.21
# Epoch #35 | Accuracy: 94.67% | Loss: 0.21
# Epoch #36 | Accuracy: 95.33% | Loss: 0.2
# Epoch #37 | Accuracy: 95.33% | Loss: 0.2
# Epoch #38 | Accuracy: 95.33% | Loss: 0.2
# Epoch #39 | Accuracy: 95.33% | Loss: 0.2

# %% [markdown]
# ### Plot accuracies and losses over entire training

# %%
plt.plot(loss_history)

plt.xlabel("Epochs")
plt.ylabel("Loss")

plt.show()

# %%
plt.plot(acc_history)

plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.show()
